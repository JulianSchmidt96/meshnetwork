# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
import ploting_utils as pu

# %%
data= {}

for i in range(1,7):
    path = f"/home/schmijul/Desktop/OpenFieldDay/parsed/router5/OpenField{i}"
    data[f'meas-{i:02}'] = pd.read_csv(f"{path}/iperfData.csv").datarate

# %%
pu.plot_cdf(data, 'datarate [bits/s]','cummulative distritbution of datarates from all scenarios')

plt.savefig('datarate_all_scenarios_cdf.png')

# %%
stds = {key: data[key].std() for key in list(data.keys())}

# %%
pu.plot_metric(stds, 'std [bits/s]')
